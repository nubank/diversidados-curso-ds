# %% [markdown]
# ## Imports

# %%
import pandas as pd
import fklearn as fk
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Lendo o dataset relevante

# %%
policy_input_dataset = pd.read_csv("data/policy_dataset.csv")

# %%
policy_input_dataset.columns
# Out:
# Index(['Unnamed: 0', 'ids', 'target_default', 'score_1', 'score_2', 'score_3',
#        'score_4', 'score_5', 'score_6', 'risk_rate', 'last_amount_borrowed',
#        'last_borrowed_in_months', 'credit_limit', 'reason', 'income',
#        'facebook_profile', 'state', 'zip', 'channel', 'job_name', 'real_state',
#        'ok_since', 'n_bankruptcies', 'n_defaulted_loans', 'n_accounts',
#        'n_issues', 'application_time_applied', 'application_time_in_funnel',
#        'email', 'external_data_provider_credit_checks_last_2_year',
#        'external_data_provider_credit_checks_last_month',
#        'external_data_provider_credit_checks_last_year',
#        'external_data_provider_email_seen_before',
#        'external_data_provider_first_name',
#        'external_data_provider_fraud_score', 'lat_lon', 'marketing_channel',
#        'profile_phone_number', 'reported_income', 'shipping_state',
#        'shipping_zip_code', 'profile_tags', 'user_agent', 'pii_cpf', 'spends',
# ...

# %%
policy_input_dataset.head(50)
# Out:
#     Unnamed: 0                                   ids  target_default  \
# 0            0  343b7e7b-2cf8-e508-b8fd-0a0285af30aa           False
# 1            1  bc2c7502-bbad-0f8c-39c3-94e881967124           False
# 2            2  669630dd-2e6a-0396-84bf-455e5009c922            True
# 3            3  d235609e-b6cb-0ccc-a329-d4f12e7ebdc1           False
# 4            4  9e0eb880-e8f4-3faa-67d8-f5cdd2b3932b           False
# 5            5  538c1908-bd80-b834-c3f0-238b4f536d3f           False
# 6            6  cd23a767-efe7-46fe-18c7-59b93f2e6e72           False
# 7            7  7552f149-5c7b-9e10-24a0-55978ee4ff5b           False
# 8            8  2bf379e3-51e3-2f7c-168f-3d494e2d2b5b           False
# 9            9  4146cbf8-1ec5-f381-e5c4-1ffad3a3e37e            True
# 10          10  0e436bba-2303-4cb1-cf1e-45df013769cc           False
# 11          11  ebbe6eab-9196-49b5-5e4a-e2bc52fa3925           False
# 12          12  e732fa2a-dcc4-e887-e0c4-6b3fddee8095           False
# ...

# %%
target_columns = ["target_defaults", "spend"]
prediction_columns = ["risk_prediction", "spend_prediction"]
acq_info = ['score_1', 'score_2', 'score_3',
       'score_4', 'score_5', 'score_6', 'risk_rate', 'last_amount_borrowed',
       'last_borrowed_in_months', 'credit_limit', 'reason', 'income',
       'facebook_profile', 'state', 'zip', 'channel', 'job_name', 'real_state',
       'ok_since', 'n_bankruptcies', 'n_defaulted_loans', 'n_accounts',
       'n_issues', 'application_time_applied', 'application_time_in_funnel',
       'email', 'external_data_provider_credit_checks_last_2_year',
       'external_data_provider_credit_checks_last_month',
       'external_data_provider_credit_checks_last_year',
       'external_data_provider_email_seen_before',
       'external_data_provider_first_name',
       'external_data_provider_fraud_score', 'lat_lon', 'marketing_channel',
       'profile_phone_number', 'reported_income', 'shipping_state',
       'shipping_zip_code', 'profile_tags', 'user_agent', 'pii_cpf']

credit_card_info = ['credit_line', 'revolving_balance']

# %% [markdown]
# ## Calcular o valor de um cliente, qual a receita real de um cliente individual?

# %% [markdown]
# ## Criar uma regra de aprovação
#
# Lembrar dos exemplos de aula: threshold, grupos, calibração

# %% [markdown]
# ## Simular as decisões a partir da regra decidida
#
# Ver quem seria aprovado ou não
#
# Ver qual seria o lucro da decisão
